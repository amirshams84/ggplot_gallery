# %%
#####################
# Library Loading
#####################
library(tidyverse)
library(ggplot2)
library(reshape2)
library(cowplot)
library(gplots)
library(tools)
library(scales)
library(stringr)
library(RColorBrewer)
library(ggsci)
library(pheatmap)
library(ComplexHeatmap)
library(ggcorrplot)
library(readxl)
library(GGally)
library(plot3D)
library(ggrepel)
library(circlize)

# %%
#####################
# Config Theme
#####################
theme_set(theme_grey())
options(repr.plot.width=10, repr.plot.height=10)

# %%
#####################
# Color Pallett
#####################
Color_Spectrum <- colorpanel(20, "blue","green","red")
GroupID_Color_List = c("Naive"="#88008A", "CCR6neg"="#FFA500", "CCR6low"="#0456f8", "CCR6int"="#1D8F06", "CCR6high"="#e51134")
GroupID_Order_List = c("Naive", "CCR6neg", "CCR6low", "CCR6int", "CCR6high")
GroupID_Label_List = c("Naive"="Naive", "CCR6neg"=expression(paste("CCR6"^neg)), "CCR6low"=expression(paste("CCR6"^low)), "CCR6int"=expression(paste("CCR6"^int)), "CCR6high"=expression(paste("CCR6"^high)))

# %%
#####################
# Input/Output
#####################
expression_file_Path = "../Data/Fluidigm_Donor123_Log2_Expression.txt"
gene_list_file_Path = "../Data/Fluidigm_Donor123_Gene_List.txt"
metadata_file_Path = "../Data/Fluidigm_Donor123_sample_design.txt"

# %%
#####################
# Read I/O
#####################
#READ I/O
expression_DF = read_tsv(expression_file_Path)
#head(expression_DF)
#dim(expression_DF)
gene_list_DF = read_tsv(gene_list_file_Path)
#head(gene_list_DF)
#dim(gene_list_DF)
metadata_DF = read_tsv(metadata_file_Path)
#head(metadata_DF)
#dim(metadata_DF)
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   GeneID = col_character()
# )
# Parsed with column specification:
# cols(
#   SampleID = col_character(),
#   GroupID = col_character()
# )

# %%
####################
#Data Wrangling
####################

#1-leftjoin with sample metadata
filtered_expression_DF = gene_list_DF %>% inner_join(expression_DF, by = c("GeneID" = "ID"))
#head(filtered_expression_DF)
#dim(filtered_expression_DF)

#2- Transpose
transposed_filtered_expression_DF = filtered_expression_DF %>%  gather(var, value, -GeneID) %>% spread(GeneID, value)
#head(transposed_filtered_expression_DF)
#dim(transposed_filtered_expression_DF)

metadata_transposed_filtered_expression_DF = metadata_DF %>% inner_join(transposed_filtered_expression_DF, by = c("SampleID" = "var"))
#head(metadata_transposed_filtered_expression_DF)

average_metadata_transposed_filtered_expression_DF = metadata_transposed_filtered_expression_DF %>% select(-c("SampleID")) %>% group_by(GroupID) %>% summarise_all(list(mean))
#head(average_metadata_transposed_filtered_expression_DF)

Gene_Correlation_Matrix = cor_pmat(average_metadata_transposed_filtered_expression_DF[,-c(1:1)], method="pearson")
head(Gene_Correlation_Matrix)
#od = hclust(dist(Gene_Correlation_Dist))$order
#Gene_Correlation_Matrix = Gene_Correlation_Dist[od, od]
#head(Gene_Correlation_Matrix)
# Out:
#       BATF      CCL20       CCR6        CXCR3      CXCR5      EOMES
# BATF  0.0000000 0.697842324 0.550213800 0.68543638 0.89145227 0.3401355
# CCL20 0.6978423 0.000000000 0.006485879 0.40801123 0.79217019 0.6699938
# CCR6  0.5502138 0.006485879 0.000000000 0.23087202 0.57391859 0.5741818
# CXCR3 0.6854364 0.408011233 0.230872020 0.00000000 0.02315028 0.3464143
# CXCR5 0.8914523 0.792170194 0.573918591 0.02315028 0.00000000 0.3233330
# EOMES 0.3401355 0.669993804 0.574181801 0.34641428 0.32333304 0.0000000
#       FOXP3     GATA3      GFI1       IFNG       ⋯ IL4         IL7R
# BATF  0.4535244 0.39015302 0.64203288 0.78798786 ⋯ 0.932233326 0.79435903
# CCL20 0.7000194 0.87634200 0.03511622 0.55257109 ⋯ 0.761669029 0.99634061
# CCR6  0.5863535 0.94777594 0.01200159 0.41894040 ⋯ 0.569668247 0.71707574
# CXCR3 0.1575254 0.71647317 0.10751999 0.03472211 ⋯ 0.030317510 0.10679693
# CXCR5 0.1325903 0.56248005 0.32402743 0.02232779 ⋯ 0.001472315 0.08844932
# EOMES 0.9780576 0.02855812 0.36533831 0.49535930 ⋯ 0.410075032 0.81517192
#       IRF4       KLRB1      RORA       RORC         SPI1       TBX21
# BATF  0.82857649 0.88457264 0.66518704 7.120116e-01 0.54984970 0.910605133
# CCL20 0.04828591 0.05231777 0.01481618 1.069031e-05 0.26614131 0.858804090
# CCR6  0.14431556 0.10756712 0.04599651 5.738051e-03 0.24280285 0.661471060
# CXCR3 0.85812488 0.83773493 0.70483415 3.971405e-01 0.25951166 0.047785413
# CXCR5 0.77436195 0.71287886 0.83636507 7.808342e-01 0.34337121 0.001659991
# EOMES 0.87777319 0.73853625 0.95823714 6.914252e-01 0.04034428 0.402387105
#       TNF       ZBTB16
# BATF  0.5710010 0.6790613
# CCL20 0.2324813 0.3011142
# CCR6  0.3741189 0.4246650
# CXCR3 0.6363969 0.5936549
# CXCR5 0.2909777 0.2308988
# EOMES 0.9884123 0.5876996

# %%
####################
# Heatmap
####################
correlation_heatmap_Object = Heatmap(Gene_Correlation_Matrix, 
        show_row_names = TRUE, 
        show_column_names = TRUE, 
        row_dend_reorder = FALSE, 
        column_dend_reorder = FALSE, 
        cluster_columns = TRUE,
        cluster_rows = TRUE,
        show_column_dend = TRUE,
        show_row_dend = TRUE,
        col = Color_Spectrum,
        #row_dend_width = unit(1.0, "cm"),
        #col_dend_width = unit(1.0, "cm"),
        #clustering_distance_rows = "pearson",
        #clustering_distance_columns = "pearson",
        #clustering_method_rows = "complete",
        #clustering_method_columns = "complete",
        rect_gp = gpar(col = "black", lwd = 0.5),
        heatmap_legend_param = list(col_fun = colors, title="", legend_height = unit(6, "cm"))
       )
correlation_heatmap_Object = plot_grid(grid.grabExpr(draw(correlation_heatmap_Object)), nrow=1)
correlation_heatmap_Object
# Out:
# plot without title

# %%
ggsave(file="../Result/Fluidigm_Donor123_GeneCorrelationHeatmap.pdf", device=cairo_pdf, plot=correlation_heatmap_Object, width = 10, height = 10, units = "in", dpi=1200)
